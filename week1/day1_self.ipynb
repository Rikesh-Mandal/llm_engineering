# %%
import os
from openai import OpenAI 
from scraper import fetch_website_contents
from dotenv import load_dotenv
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
if not api_key:
    print('No API key found!')
elif not api_key.startswith('sk-proj-'):
    print('API key found but does not start with sk-proj-, please check for the correct API key!')
elif api_key.strip() != api_key:
    print('There might be leading or trailing spaces in the key, please check!')
else:
    print('API key found!')
# Out:
# API key found!

# %%
message = 'Hello, you name shall be Linus from now onwards, and my name is Rikesh'
messages = [
    {'role': 'system', 'content': 'You are the top professional in the field of AI Engineering. After every response, add a quick information about AI engineering that can help a beginner to become a better AI Engineer and it should be structured.'},
    {'role': 'user', 'content': message}
    ]
messages
# Out:
# [{'role': 'system',
#   'content': 'You are the top professional in the field of AI Engineering. After every response, add a quick information about AI engineering that can help a beginner to become a better AI Engineer and it should be structured.'},
#  {'role': 'user',
#   'content': 'Hello, you name shall be Linus from now onwards, and my name is Rikesh'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(model='gpt-5-nano', messages=messages)
print(response.choices[0].message.content)
# Out:
# Hi Rikesh! I can go by Linus for this chat. Nice to meet you. How can I help today? Are you looking to learn AI engineering fundamentals, work on a project, or discuss a specific topic?
#
# AI Engineering Tip for Beginners (Structured):
# - Foundation: Strengthen Python and essential math (linear algebra, probability) plus basic data handling (NumPy, pandas).
# - ML Lifecycle: Learn problem formulation, data collection/cleansing, feature engineering, model training, evaluation, deployment, and monitoring.
# - Practice: Do 2–3 end-to-end projects with clear documentation and version control.
# - Ethics & Reproducibility: Consider bias and privacy, and keep experiments reproducible with proper tracking and reproducible code.

# %%
rm = fetch_website_contents('https://ornate-torte-03c391.netlify.app/')
print(rm)
# Out:
# Rikesh Mandal
#
# Rikesh Mandal
# About
# Experience
# Projects
# Contact
# Rikesh Mandal
# About
# Experience
# Projects
# Contact
# Hello I'm
# Rikesh Mandal
# Software Developer
# Download CV
# Contact Info
# Get to Know More
# About Me
# Experience
# 1+ years
# Backend Development
# Education
# MSc Artificial Intelligence
# BSc Computer Networking and IT Security
# Loading...
# Explore My
# Experience
# Frontend Development
# HTML
# Experienced
# CSS
# Experienced
# JavaScript
# Intermediate
# Materials UI
# Basic
# Backend Development
# Java
# Experienced
# SpringBoot
# Basic
# Python
# Intermediate
# Django
# Basic
# SQL
# Experienced
# PostgreSQL
# Basic
# Browse My Recent
# Projects
# Microblog
# Github
# Live Demo
# Image to 3D
# Github
# Live Demo(W.I.P)
# Animal Image Classification
# Github
# Live Demo(W.I.P)
# Get in Touch
# Contact Me
# rikeshmandal26@gmail.com
# Linkedin
# About
# Experience
# Projects
# Contact
# Copyright © 2025 Rikesh Mandal. All Rights Reserved.

# %%
system_prompt = 'You are an expert software engineer. With every reponse you provide, give one structured tip or knowledge or information on tools and techniques and also on how to be a better software engingeer, it can be regarding backend development, frontend, system design or dsa.'
user_prompt = 'Take a look at this website, and provide constructive criticism to the creator.'
print(system_prompt)
print(user_prompt)
# Out:
# You are an expert software engineer. With every reponse you provide, give one structured tip or knowledge or information on tools and techniques and also on how to be a better software engingeer, it can be regarding backend development, frontend, system design or dsa.
# Take a look at this website, and provide constructive criticism to the creator.

# %%
def messages_for(website):
    return [
    {'role': 'system', 'content': system_prompt},
    {'role': 'user', 'content': user_prompt + website}
    ]

# %%
response = openai.chat.completions.create(model='gpt-5-nano', messages=request_body)
print(response.choices[0].message.content)
# Out:
# I don’t see a link to the site. If you share the URL (or paste a snapshot of the pages you want reviewed), I can give tailored, door-by-door feedback. In the meantime, here’s a structured framework you can use to critique any website effectively, plus two actionable tips you can apply right away.
#
# Two quick, concrete tips (one tool/technique, one engineer-growth tip)
# - Tool/technique tip: Use Lighthouse (built into Chrome DevTools) and PageSpeed Insights to get an objective, repeatable set of metrics (Performance, Accessibility, Best Practices, SEO). For ongoing quality, wire Lighthouse CI into your CI/CD so regressions are caught automatically.
# - Engineer-growth tip: Write critiques as actionable PR feedback. Start with what’s working, then list issues with concrete, testable fixes, owners, and acceptance criteria. Practice this in 1–2 sentence bullets per issue to keep reviews focused and constructive.
#
# Comprehensive critique framework (go-to checklist)
# 1) Performance
# - What to check:
#   - Core web vitals: Largest Contentful Paint (LCP), First Input Delay (FID), Cumulative Layout Shift (CLS).
#   - Resource sizing: unminified assets, large images, unused CSS/JS.
#   - Critical path: render-blocking resources, JavaScript execution time.
# - How to fix (examples):
#   - Compress and serve images in proper formats (WebP/AVIF), implement responsive image sizing.
#   - Lazy-load off-screen images and non-critical resources; code-split JavaScript bundles.
#   - Minify CSS/JS, remove unused code, and inline critical CSS for above-the-fold content.
#   - Enable HTTP/2+ and use a CDN; preconnect to critical origins.
# - How to measure impact: compare LCP/FID/CLS before vs after; aim for LCP under 2.5s, CLS under 0.1–0.25, FID under 100–200ms on relevant devices.
#
# 2) Accessibility (a11y)
# - What to check:
#   - Semantic HTML, proper heading order, ARIA where appropriate.
#   - Color contrast (WCAG AA 4.5:1 for body text).
#   - Keyboard navigability (focus order, visible focus outlines).
#   - Alt text for images; meaningful link text; ARIA roles only when necessary.
# - How to fix:
#   - Ensure heading structure is logical; use semantic elements (header, nav, main, footer).
#   - Fix color combos that fail contrast; provide text alternatives for non-text content.
#   - Test with a keyboard alone; run an accessibility scanner and manual screen-reader checks.
# - How to measure impact: accessibility scores in Lighthouse; manual checks across assistive tech.
#
# 3) User Experience (UX) and content clarity
# - What to check:
#   - Value proposition above the fold; clear primary action; intuitive navigation.
#   - Consistent visual language: typography, spacing, and component reuse.
#   - Form usability: labels, inline validation, accessible error messaging.
# - How to fix:
#   - A/B test hero variants; ensure CTAs are prominent and unambiguous.
#   - Create or refine a design system with reusable components and documented interaction patterns.
#   - Simplify forms with inline validation and helpful error messages.
# - How to measure impact: task success rate, average time to complete a task, user satisfaction scores.
#
# 4) Search Engine Optimization (SEO) and discoverability
# - What to check:
#   - Page titles, meta descriptions, canonical tags, structured data where appropriate.
#   - Clear heading hierarchy (H1, H2, H3…) and descriptive alt text.
#   - XML sitemap and robots.txt; proper 301 redirects for moved content.
# - How to fix:
#   - Write unique, benefit-focused titles and meta descriptions per page.
#   - Implement structured data (where relevant) to improve rich results.
# - How to measure impact: organic traffic, rankings for key terms, click-through rate from search results.
#
# 5) Security and privacy
# - What to check:
#   - Use HTTPS everywhere; modern TLS configuration; secure cookies.
#   - Proper input validation to prevent injection attacks; CSRF protection on state-changing requests.
#   - Content Security Policy (CSP) and security headers (X-Content-Type-Options, X-Frame-Options, etc.).
# - How to fix:
#   - Review data handling: minimize data collection, anonymize where possible, add privacy notices.
#   - Regular dependency updates and vulnerability scans.
# - How to measure impact: security scan results; incidents reduced or eliminated; compliance with privacy requirements.
#
# 6) Reliability, maintainability, and DevEx
# - What to check:
#   - Code organization, naming, and test coverage; clear separation of concerns.
#   - Test pyramid: unit, integration, end-to-end tests; flakiness reduction.
#   - CI/CD automation, with reproducible builds and rollback plans.
# - How to fix:
#   - Introduce or refactor to a small, cohesive component library or design system.
#   - Increase test coverage for critical paths; add contract tests for APIs.
#   - Document deployment steps and do blue/green or canary releases where feasible.
# - How to measure impact: reduced bug rate, faster on-ramps for new contributors, shorter release cycles.
#
# 7) Data, analytics, and feedback loops
# - What to check:
#   - Are key events tracked (e.g., conversions, feature usage) with privacy in mind?
#   - Is there a mechanism for user feedback and issue reporting?
# - How to fix:
#   - Instrument meaningful, privacy-preserving analytics; provide dashboards for product decisions.
#   - Add lightweight feedback channels (in-app surveys, contact forms) and triage flow.
# - How to measure impact: better product decisions from data; quantifiable improvements in the metrics tied to those events.
#
# 8) Deployment, observability, and scalability
# - What to check:
#   - Clear deployment process, rollback plans, and environment parity.
#   - Error tracking, logs, dashboards, and alerting for health signals.
#   - Scalability considerations for expected traffic growth.
# - How to fix:
#   - Implement feature flags to reduce risk; add tracing for performance bottlenecks.
#   - Set up dashboards (APM, logs) and alert thresholds that notify you before users are impacted.
# - How to measure impact: uptime, mean time to recovery (MTTR), and capacity-ready growth metrics.
#
# How to present feedback to the creator
# - Start with positives: what’s already working and why it matters.
# - Be specific and actionable: for every issue, include a suggested fix, rationale, and priority.
# - Include metrics or references: link to tools or pages (Lighthouse scores, accessibility checks, etc.) to back up your points.
# - Offer ownership and a plan: suggest owners for fixes and a rough timeline to track progress.
# - Be empathetic and constructive: frame changes as improvements that help users and developers alike.
#
# If you provide the URL or more page specifics (e.g., “homepage and pricing page”), I’ll tailor the critique with concrete, page-level issues and targeted recommendations.
#
# Two more practical notes you can try right now
# - Quick win checklist for any page: run Lighthouse, check for images over 1 MB, check for any non-semantic div usage for major blocks, verify focus visibility, and confirm the page has a meaningful title and meta description.
# - Small experiments to validate UX quickly: A/B test with a simpler hero or a clearer primary CTA on the homepage; measure impact via a short user study or analytics.
#
# If you share the site or screenshots, I’ll provide a targeted, prioritized critique with concrete fixes you can act on.
#
# Would you like me to tailor this to a specific page (e.g., home, product detail, pricing) once you share the URL?
