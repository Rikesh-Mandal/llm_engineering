# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4-mini")
tokens = encoding.encode("Hello my name is Rikesh.")

# %%
print(tokens)
# Out:
# [9906, 856, 836, 374, 432, 1609, 4385, 13]

# %%
for tokenId in tokens:
    token_text = encoding.decode([tokenId])
    print(f"tokenId: {tokenId} - {token_text}")
# Out:
# tokenId: 9906 - Hello
# tokenId: 856 -  my
# tokenId: 836 -  name
# tokenId: 374 -  is
# tokenId: 432 -  R
# tokenId: 1609 - ik
# tokenId: 4385 - esh
# tokenId: 13 - .

# %%
encoding.decode([666])
# Out:
# ' Th'

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.environ.get("OPENAI_API_KEY")
openai = OpenAI()

# %%
system_prompt = "You are a helpful stoic assistant."
user_prompt = "Hi my name is Rikesh, I struggle with giving continuity to study, I am studying hard to become and AI engineer."

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
    ]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hi Rikesh, it’s great that you’re committed to becoming an AI engineer. Maintaining continuity in studying can be challenging, but here are some stoic-inspired tips to help you stay consistent:
#
# 1. Focus on what you can control: Concentrate on your daily effort rather than worrying about the end result. Each day, commit to studying for a set amount of time or completing specific topics.
#
# 2. Establish a routine: Create a study schedule and stick to it. Consistency comes from habits, and habits come from repeated actions.
#
# 3. Embrace obstacles as opportunities: When you struggle to maintain continuity, view it as a chance to strengthen your discipline and resilience.
#
# 4. Reflect daily: At the end of each day, review what you learned and what could be improved. This reflection builds awareness and motivates progress.
#
# 5. Break your goals into small, manageable tasks: Instead of overwhelming yourself with the big picture, focus on achievable daily tasks.
#
# ...

# %%
messages = [{"role": "system", "content": "you are a helpful assistant"},
            {"role": "user", "content": "what is my name, and what is the problem I am currently facing?"}            
            ]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# I’m sorry, but I don’t know your name or the problem you are currently facing based on the information provided. Could you please share more details?

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt},
    {"role": "assistant", "content": "Hi Rikesh, it’s great that you’re committed to becoming an AI engineer. Maintaining continuity in studying can be challenging, but here are some stoic-inspired tips to help you stay consistent"},
    {"role": "user", "content": "what is my name, and what is the problem I am currently facing?"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-4", messages=messages)
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-ERjpnQaFuH0S6uLSV0dMnKA0CPTKt",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "Your name is Rikesh and you're currently facing difficulties with maintaining continuity in your studies, specifically as you prepare to become an AI engineer.",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1790279751,
#   "model": "gpt-4-0613",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": null,
#   "usage": {
#     "completion_tokens": 29,
#     "prompt_tokens": 108,
#     "total_tokens": 137,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
# ...

# %%
print(response.choices[0].message.content)
# Out:
# Your name is Rikesh and you're currently facing difficulties with maintaining continuity in your studies, specifically as you prepare to become an AI engineer.
